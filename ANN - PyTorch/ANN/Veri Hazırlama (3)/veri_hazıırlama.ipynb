# %% [markdown]
# # MİNİK HATIRLATMA

# %% [markdown]
# * Aşağıda yapılan işlemler en temel veri hazırlama süreçleridir.Eğer önceden Tensorflow / Keras ile uğraştıysanız bu konuları çok rahat anlarsınız.Ama eğer ANN le alakalı kod ya da teorik temeliniz yoksa sizden ricam bu repoya göz gezdirmeniz.
#
# * `"https://github.com/huseyin-dgn/Deep-Learning-Fundamentals" `,

# %% [markdown]
# ----

# %% [markdown]
# ## 1️⃣ Gerekli Kütüphaneler
# *# Torch ve veri işleme kütüphaneleri*
#
# ## 2️⃣ Veri Yükleme
# *# CSV veya veri kaynağından veri alınır*
#
# ## 3️⃣ Özellik ve Hedef Ayırma
# *# X: özellikler, y: hedef*
#
# ## 4️⃣ Eğitim/Test Seti Bölme
# *# Veriyi eğitim ve test olarak ayırma*
#
# ## 5️⃣ Özellikleri Normalleştirme
# *# Standardizasyon veya normalizasyon*
#
# ## 6️⃣ Tensorlara Çevirme
# *# PyTorch tensor formatına dönüştürme*
#
# ## 7️⃣ Dataset ve DataLoader Oluşturma
# *# Veriyi ANN için hazır hale getirme*

# %% [markdown]
# ---

# %% [markdown]
# # 1️⃣ 🔧 Gerekli Kütüphaneler ve Importlar

# %%
# 1️⃣ 🔧 Gerekli Kütüphaneler ve Importlar
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np

# %% [markdown]
# # 2️⃣ 📂 Veri Yükleme

# %%
df = pd.read_csv(r"C:\Users\hdgn5\OneDrive\Masaüstü\pytorch fundementals\ANN\Datasets\cancer.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df = df.drop(columns=["Unnamed: 32"])
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # 3️⃣ 🎯 Özellik ve Hedef Ayırma

# %%
x = df.drop("diagnosis" ,axis=1).values
y = df["diagnosis"].values

le = LabelEncoder()
y = le.fit_transform(y)  # "M"/"B" → 1/0

# %% [markdown]
# # 4️⃣ 📝 Eğitim/Test Seti Bölme

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %% [markdown]
# # 5️⃣ ⚖️ Özellikleri Normalleştirme

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  # 🔹 Eğitim verisini öğrenip dönüştür
X_test = scaler.transform(X_test)        # 🔹 Test verisini aynı ölçekle dönüştür

# %% [markdown]
# # 6️⃣ 🔢 Tensorlara Çevirme

# %%
import torch

X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
y_test = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# %% [markdown]
# * squeeze() → Tensor’un boyutu 1 olan eksenlerini kaldırır
#
# * Sonuç: shape (num_samples,) → 1D tensor
#
# * Artık DataLoader, her örneği tek bir float tensor olarak alabilir ve mini-batch oluşturabilir

# %%
y_train = torch.tensor(y_train, dtype=torch.float32).squeeze()
y_test = torch.tensor(y_test, dtype=torch.float32).squeeze()
# Out:
# C:\Users\hdgn5\AppData\Local\Temp\ipykernel_20584\1977320995.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y_train, dtype=torch.float32).squeeze()
# C:\Users\hdgn5\AppData\Local\Temp\ipykernel_20584\1977320995.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y_test, dtype=torch.float32).squeeze()

# %% [markdown]
# # 7️⃣ 📦 Dataset ve DataLoader Oluşturma

# %% [markdown]
#  # 📦 DataLoader Nedir?
#
# `DataLoader`, PyTorch’ta **Dataset’ten veri çekmek ve modelin eğitimine hazır hâle getirmek için kullanılan bir sınıftır**.
#
# ### Temel İşlevleri
#
# 1. **Mini-batch’ler oluşturur**
#    - Büyük veri kümelerini küçük parçalar halinde modele verir.
#    - Hafıza tasarrufu ve daha stabil öğrenme sağlar.
#
# 2. **Veriyi karıştırabilir (shuffle)**
#    - `shuffle=True` ile her epoch başında veriyi karıştırır.
#
# 3. **Multi-thread ile veri yükler (num_workers)**
#    - Büyük veri kümelerinde veriyi arka planda hızlıca hazırlar.
#
#
# ### Kullanımı
#
# - Önce bir **Dataset** sınıfı oluşturulur.
# - Dataset, `__len__` ve `__getitem__` metodlarını implement eder.
# - Dataset’i `DataLoader`’a veririz:

# %% [markdown]
# # 📂 Dataset Nedir?
#
# `Dataset`, PyTorch’ta **veri kaynağını temsil eden sınıftır**.
#
# - Veri kümesini **tek bir nesne altında toplar**.
# - `DataLoader` ile birlikte kullanıldığında veriyi modelin anlayacağı şekilde hazırlar.
#
# ## Temel Görevleri
#
# 1. **Veri Saklama**
#    - Tüm özellikler (X) ve hedefler (y) Dataset içinde tutulur.
#
# 2. **Veriye Erişim Sağlama**
#    - `__getitem__(self, idx)` → İndex numarasına göre tek bir örneği verir.
#
# 3. **Veri Uzunluğu Sağlama**
#    - `__len__(self)` → Dataset’in toplam örnek sayısını verir.

# %% [markdown]
# ## Kodun yapısına geçmeden önce size __len__ ve __getitem__ fonksiyonlarının ne işe yaradığını anlatayım.Burada kullanılacak Dataset ve Loaderların işlevselliğinin daha geniş olması için aşağıdaki bilgileri bırakıyorum

# %% [markdown]
# * __len__ → Toplam örnek sayısını döndürür
#
# * __getitem__ → İlgili indeksteki örneği döndürür

# %% [markdown]
# `x → Modelin giriş verisi`
#
# `y → Modelin tahmin edeceği çıkış (target)`
#
# * Yani Dataset ve DataLoader oluştururken de bu x ve y tensorlarını kullanıyoruz.

# %% [markdown]
# ### 📂 Dataset

# %%
from torch.utils.data import Dataset

class MyDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    
    def __len__(self):
        return self.X.shape[0]   # len yerine shape[0] kullanmak daha güvenli
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %% [markdown]
# ### 📦 DataLoader

# %%
from torch.utils.data import DataLoader

train_dataset = MyDataset(X_train, y_train)
test_dataset = MyDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ------------

# %% [markdown]
# ## Şimdi bütün bu kodların birleşimine bakalım.Ve sonrasında model oluşturmaya geçelim.

# %%
df = pd.read_csv(r"C:\Users\hdgn5\OneDrive\Masaüstü\pytorch fundementals\ANN\Datasets\cancer.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df = df.drop(columns=["Unnamed: 32"],axis = 1)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
x = df.drop("diagnosis",axis=1).values
y = df["diagnosis"].values

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  
X_test = scaler.transform(X_test)

# %%
X_train = torch.tensor(X_train,dtype=torch.float32)
X_test = torch.tensor(X_test , dtype=torch.float32)

# %%
y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
y_test = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# %%
class MyDataset(Dataset):
    def __init__(self,x,y):
        self.x = x
        self.y = y
    
    def __len__(self):
        return self.x.shape[0]
    
    def __getitem__(self, ix):
        return self.x[ix] , self.y[ix]

# %%
train_dataset = MyDataset(X_train,y_train)
test_dataset = MyDataset(X_test,y_test)

train_loader = DataLoader(train_dataset , batch_size = 32 , shuffle =True)
test_loader = DataLoader(test_dataset , batch_size=32 , shuffle=False)
